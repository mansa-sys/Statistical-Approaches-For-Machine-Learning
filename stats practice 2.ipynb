# %%
#5
Q = [24,29,18,17,34,71]
print(sum(Q))
# Out:
# 193

# %%
print(len(Q))
# Out:
# 6

# %%
mean = sum(Q)/len(Q)
print(mean)
# Out:
# 32.166666666666664

# %%
#6
S = [3,6,4,8]
print(sum(S))
# Out:
# 21

# %%
print(len(S))
# Out:
# 4

# %%
mean = sum(S)/len(S)
print(mean)
# Out:
# 5.25

# %%
#7
F =[ 13,63,42,81]
print (sum(F))
# Out:
# 199

# %%
print(count
      (F))
# Out:
# 4

# %%
mean = sum(F)/len(F)
print(mean)
# Out:
# 49.75
